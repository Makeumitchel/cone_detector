# %% [markdown]
# Before using, make sure the folder cone_detector has been uploaded to your GG drive. Then import your images to cone_detector/data/dd_mm_yyyy.

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Define local directory

# %%
# %cd /content/drive/MyDrive/cone_detector/
# !ls
# Out:
# /content/drive/MyDrive/cone_detector
# data	       detect.py  notebook.ipynb  __pycache__	    utils_.ipynb
# detect_.ipynb  models	  predictions	  requirements.txt  utils.py

# %% [markdown]
# Initialize detector. Give images directory as an argument.

# %%
from detect import Detector
d=Detector('24_11_2021')

# %% [markdown]
# Run through the images folder. Predictions will be saved to ./cone_detector/predictions/prediction_24_11_2021.csv

# %%
d.run_through_folder('24_11_2021')
# Out:
# Image: tree5-4x59.jpg ; pred_2d =  272 ; pred_3d =  527
# Image: tree2-1x60.jpg ; pred_2d =  210 ; pred_3d =  376
# Image: tree3-1x61.jpg ; pred_2d =  74 ; pred_3d =  97
# Image: tree4-3x61.jpg ; pred_2d =  641 ; pred_3d =  1606
# Image: tree1-3x58.jpg ; pred_2d =  213 ; pred_3d =  383
# Predictions saved to drive/MyDrive/cone_detector/ ./predictions/prediction_24_11_2021.csv

# %% [markdown]
# Detect cones on a single image

# %%
d.detect('tree1-3x58.jpg')
